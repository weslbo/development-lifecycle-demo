# %%
print("inside feature/data-validation")

# %%
# Data validation logic
df_validated = df.filter(col("customer_id").isNotNull())
df_validated = df_validated.filter(col("order_date") >= "2024-01-01")
